# %% [markdown]
# #📌 Extracción

# %% [markdown]
# ###Extracción de datos

# %% [markdown]
# ✅ Cargar los datos directamente desde la API utilizando Python.

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/ingridcristh/challenge2-data-science-LATAM/main/TelecomX_Data.json"

# %% [markdown]
# ✅ Convertir los datos a un DataFrame de Pandas para facilitar su manipulación.

# %%
df = pd.read_json(url)

df.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
df.sample(15)
# Out:
#       customerID Churn                                           customer  \
# 2433  3398-GCPMU    No  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 3111  4332-MUOEZ    No  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 100   0164-XAIRP    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 5468  7495-OOKFY   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 2657  3703-TTEPD    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 1590  2260-USTRB   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 2938  4080-OGPJL   Yes  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 2525  3523-BRGUW    No  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 763   1089-HDMKP    No  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 5277  7206-PQBBZ    No  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4978  6810-VCAEX    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 6975  9609-BENEA    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #🔧 Transformación

# %% [markdown]
# ###Conoce el conjunto de datos

# %% [markdown]
# ✅ Explorar las columnas del dataset y verificar sus tipos de datos.

# %%
df.shape
# Out:
# (7267, 6)

# %%
df.columns
# Out:
# Index(['customerID', 'Churn', 'customer', 'phone', 'internet', 'account'], dtype='object')

# %%
df['customerID']
# Out:
# 0       0002-ORFBO
# 1       0003-MKNFE
# 2       0004-TLHLJ
# 3       0011-IGKFF
# 4       0013-EXCHZ
#            ...
# 7262    9987-LUTYD
# 7263    9992-RRAMN
# 7264    9992-UJOEL
# 7265    9993-LHIEB
# 7266    9995-HOTOH
# Name: customerID, Length: 7267, dtype: object

# %%
df['Churn']
# Out:
# 0        No
# 1        No
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 7262     No
# 7263    Yes
# 7264     No
# 7265     No
# 7266     No
# Name: Churn, Length: 7267, dtype: object

# %%
df['customer']
# Out:
# 0       {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1       {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2       {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3       {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4       {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#                               ...
# 7262    {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263    {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264    {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265    {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266    {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# Name: customer, Length: 7267, dtype: object

# %%
df['phone']
# Out:
# 0          {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1         {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2          {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3          {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4          {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#                               ...
# 7262       {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7263      {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 7264       {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7265       {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7266    {'PhoneService': 'No', 'MultipleLines': 'No ph...
# Name: phone, Length: 7267, dtype: object

# %%
df['internet']
# Out:
# 0       {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1       {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2       {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3       {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4       {'InternetService': 'Fiber optic', 'OnlineSecu...
#                               ...
# 7262    {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7263    {'InternetService': 'Fiber optic', 'OnlineSecu...
# 7264    {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7265    {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7266    {'InternetService': 'DSL', 'OnlineSecurity': '...
# Name: internet, Length: 7267, dtype: object

# %%
df['account']
# Out:
# 0       {'Contract': 'One year', 'PaperlessBilling': '...
# 1       {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2       {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3       {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4       {'Contract': 'Month-to-month', 'PaperlessBilli...
#                               ...
# 7262    {'Contract': 'One year', 'PaperlessBilling': '...
# 7263    {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7264    {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7265    {'Contract': 'Two year', 'PaperlessBilling': '...
# 7266    {'Contract': 'Two year', 'PaperlessBilling': '...
# Name: account, Length: 7267, dtype: object

# %%
df.dtypes
# Out:
# customerID    object
# Churn         object
# customer      object
# phone         object
# internet      object
# account       object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %% [markdown]
# ✅ Consultar el diccionario para comprender mejor el significado de las variables.

# %% [markdown]
# TelecomX_diccionario.md
#
#
# https://github.com/alura-cursos/challenge2-data-science-LATAM/blob/5adf5f2f87a72bd8b2e854db16e2f2f7c499081a/TelecomX_diccionario.md

# %% [markdown]
# ✅ Identificar las columnas más relevantes para el análisis de evasión.

# %%
df[['customerID','Churn']]
# Out:
#       customerID Churn
# 0     0002-ORFBO    No
# 1     0003-MKNFE    No
# 2     0004-TLHLJ   Yes
# 3     0011-IGKFF   Yes
# 4     0013-EXCHZ   Yes
# ...          ...   ...
# 7262  9987-LUTYD    No
# 7263  9992-RRAMN   Yes
# 7264  9992-UJOEL    No
# 7265  9993-LHIEB    No
# 7266  9995-HOTOH    No
#
# [7267 rows x 2 columns]

# %% [markdown]
# ###Comprobación de incoherencias en los datos

# %%
norm1 = pd.json_normalize(df['customer'])
norm2 = pd.json_normalize(df['phone'])
norm3 = pd.json_normalize(df['internet'])
norm4 = pd.json_normalize(df['account'])

norm1
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure
# 0     Female              0     Yes        Yes       9
# 1       Male              0      No         No       9
# 2       Male              0      No         No       4
# 3       Male              1     Yes         No      13
# 4     Female              1     Yes         No       3
# ...      ...            ...     ...        ...     ...
# 7262  Female              0      No         No      13
# 7263    Male              0     Yes         No      22
# 7264    Male              0      No         No       2
# 7265    Male              0     Yes        Yes      67
# 7266    Male              0     Yes        Yes      63
#
# [7267 rows x 5 columns]

# %%
norm2
# Out:
#      PhoneService     MultipleLines
# 0             Yes                No
# 1             Yes               Yes
# 2             Yes                No
# 3             Yes                No
# 4             Yes                No
# ...           ...               ...
# 7262          Yes                No
# 7263          Yes               Yes
# 7264          Yes                No
# 7265          Yes                No
# 7266           No  No phone service
#
# [7267 rows x 2 columns]

# %%
norm3
# Out:
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0                DSL             No          Yes               No         Yes
# 1                DSL             No           No               No          No
# 2        Fiber optic             No           No              Yes          No
# 3        Fiber optic             No          Yes              Yes          No
# 4        Fiber optic             No           No               No         Yes
# ...              ...            ...          ...              ...         ...
# 7262             DSL            Yes           No               No         Yes
# 7263     Fiber optic             No           No               No          No
# 7264             DSL             No          Yes               No          No
# 7265             DSL            Yes           No              Yes         Yes
# 7266             DSL            Yes          Yes              Yes          No
#
#      StreamingTV StreamingMovies
# ...

# %%
norm4
# Out:
#             Contract PaperlessBilling     PaymentMethod  Charges.Monthly  \
# 0           One year              Yes      Mailed check            65.60
# 1     Month-to-month               No      Mailed check            59.90
# 2     Month-to-month              Yes  Electronic check            73.90
# 3     Month-to-month              Yes  Electronic check            98.00
# 4     Month-to-month              Yes      Mailed check            83.90
# ...              ...              ...               ...              ...
# 7262        One year               No      Mailed check            55.15
# 7263  Month-to-month              Yes  Electronic check            85.10
# 7264  Month-to-month              Yes      Mailed check            50.30
# 7265        Two year               No      Mailed check            67.85
# 7266        Two year               No  Electronic check            59.00
#
#      Charges.Total
# 0            593.3
# 1            542.4
# 2           280.85
# ...

# %%
df = pd.DataFrame({
    'customerID':df['customerID'],
    'Churn':df['Churn'],
    'gender':norm1['gender'],
    'SeniorCitizen':norm1['SeniorCitizen'],
    'Partner':norm1['Partner'],
    'Dependents':norm1['Dependents'],
    'tenure':norm1['tenure'],
    'PhoneService':norm2['PhoneService'],
    'MultipleLines':norm2['MultipleLines'],
    'InternetService':norm3['InternetService'],
    'OnlineSecurity':norm3['OnlineSecurity'],
    'OnlineBackup':norm3['OnlineBackup'],
    'DeviceProtection':norm3['DeviceProtection'],
    'TechSupport':norm3['TechSupport'],
    'StreamingTV':norm3['StreamingTV'],
    'StreamingMovies':norm3['StreamingMovies'],
    'Contract':norm4['Contract'],
    'PaperlessBilling':norm4['PaperlessBilling'],
    'PaymentMethod':norm4['PaymentMethod'],
    'Charges.Monthly':norm4['Charges.Monthly'],
    'Charges.Total':norm4['Charges.Total']
})
df
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines InternetService  ... OnlineBackup  \
# ...

# %%
df.shape
# Out:
# (7267, 21)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df.dtypes
# Out:
# customerID           object
# Churn                object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# Charges.Monthly     float64
# Charges.Total        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %%
df.sample(15)
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 2500  3489-HHPFY    No  Female              0     Yes         No       2
# 275   0397-ZXWQF    No    Male              0      No         No      67
# 3576  4927-WWOOZ    No    Male              0     Yes         No       2
# 5769  7879-CGSFV    No    Male              0      No         No      55
# 2304  3209-ZPKFI    No    Male              0     Yes        Yes      47
# 3331  4635-EJYPD    No    Male              0     Yes        Yes      32
# 4375  5996-DAOQL    No    Male              0      No         No       1
# 5574  7621-VPNET    No  Female              0     Yes         No      42
# 3690  5087-SUURX   Yes  Female              0     Yes         No      18
# 2234  3118-UHVVQ    No  Female              0     Yes         No      68
# 3434  4759-PXTAN    No  Female              0     Yes         No      59
# 43    0071-NDAFP    No    Male              0     Yes        Yes      25
# ...

# %%
df['customerID'] = df['customerID'].unique()
df
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines InternetService  ... OnlineBackup  \
# ...

# %%
df['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
#         224
# Name: count, dtype: int64

# %%
#df.query('Churn == "No"')
#df.query('Churn == "Yes"')
#df.query('Churn == ""')

# %%
df.isnull().sum()
# Out:
# customerID          0
# Churn               0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# Charges.Monthly     0
# Charges.Total       0
# dtype: int64

# %%
churn_negativo = df['Churn'] == "No"

# %%
df[churn_negativo]
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 5     0013-MHZWF    No  Female              0      No        Yes       9
# 6     0013-SMEOE    No  Female              1     Yes         No      71
# 7     0014-BMAQU    No    Male              0     Yes         No      63
# ...          ...   ...     ...            ...     ...        ...     ...
# 7259  9979-RGMZT    No  Female              0      No         No       7
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines InternetService  ... OnlineBackup  \
# ...

# %%
churn_positivo = df['Churn'] == "Yes"

# %%
df[churn_positivo]
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# 18    0022-TCJCI   Yes    Male              1      No         No      45
# 19    0023-HGHWL   Yes    Male              1      No         No       1
# ...          ...   ...     ...            ...     ...        ...     ...
# 7243  9961-JBNMK   Yes    Male              1      No         No      21
# 7246  9965-YOKZB   Yes    Male              1      No         No       9
# 7260  9985-MWVIX   Yes  Female              0      No         No       1
# 7261  9986-BONCE   Yes  Female              0      No         No       4
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
#
#      PhoneService     MultipleLines InternetService  ...         OnlineBackup  \
# ...

# %%
churn_nulo = df['Churn'] == ""

# %%
df[churn_nulo]
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 30    0047-ZHDTW        Female              0      No         No      11
# 75    0120-YZLQA          Male              0      No         No      71
# 96    0154-QYHJU          Male              0      No         No      29
# 98    0162-RZGMZ        Female              1      No         No       5
# 175   0274-VVQOQ          Male              1     Yes         No      65
# ...          ...   ...     ...            ...     ...        ...     ...
# 7158  9840-GSRFX        Female              0      No         No      14
# 7180  9872-RZQQB        Female              0     Yes         No      49
# 7211  9920-GNDMB          Male              0      No         No       9
# 7239  9955-RVWSC        Female              0     Yes        Yes      67
# 7247  9966-VYRTZ        Female              0     Yes        Yes      31
#
#      PhoneService     MultipleLines InternetService  ...         OnlineBackup  \
# ...

# %% [markdown]
# ###Manejo de inconsistencias

# %%
df.dtypes
# Out:
# customerID           object
# Churn                object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# Charges.Monthly     float64
# Charges.Total        object
# dtype: object

# %%
import numpy as np

# %%
#Asistencia de IA
df['Charges.Total'] = df['Charges.Total'].replace(r'^\s*$', np.nan, regex=True)

df['Charges.Total'] = pd.to_numeric(df['Charges.Total'], errors='coerce')

df['Charges.Total'] = df['Charges.Total'].astype(np.float64)

# %%
df.dtypes
# Out:
# customerID           object
# Churn                object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# Charges.Monthly     float64
# Charges.Total       float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %%
columnas_a_tratar = ['Churn','gender','Partner','Dependents','PhoneService','MultipleLines','InternetService','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies','Contract','PaperlessBilling','PaymentMethod']

# %%
for col in columnas_a_tratar:
    df[col] = df[col].str.lower()

# %%
df.sample(5)
# Out:
#       customerID Churn gender  SeniorCitizen Partner Dependents  tenure  \
# 5723  7817-OMJNA    no   male              0      no         no      14
# 7173  9863-JZAIC   yes   male              0      no         no      35
# 6012  8212-DJRCH    no   male              0     yes        yes       5
# 6342  8727-JQFHV    no   male              0     yes        yes      57
# 1706  2424-WVHPL    no   male              1      no         no       1
#
#      PhoneService MultipleLines InternetService  ...         OnlineBackup  \
# 5723          yes            no              no  ...  no internet service
# 7173          yes            no             dsl  ...                   no
# 6012          yes            no     fiber optic  ...                   no
# 6342          yes            no              no  ...  no internet service
# 1706          yes            no     fiber optic  ...                   no
#
#          DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
#Asistencia de IA
df['PaymentMethod'] = df['PaymentMethod'].str.replace(r'\(|\)',' ', regex=True)

df['Contract'] = df['Contract'].str.replace('-',' ')

# %%
df.sample(5)
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 726   1041-RXHRA   yes  female              0      no         no      41
# 245   0365-TRTPY    no  female              0      no         no      37
# 6249  8601-QACRS   yes  female              0      no         no       5
# 3106  4324-AHJKS    no  female              0      no         no       5
# 1808  2577-GVSIL    no    male              0     yes        yes      35
#
#      PhoneService MultipleLines InternetService  ... OnlineBackup  \
# 726           yes            no     fiber optic  ...           no
# 245           yes           yes     fiber optic  ...          yes
# 6249          yes           yes             dsl  ...           no
# 3106          yes            no             dsl  ...           no
# 1808          yes           yes             dsl  ...           no
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
for col in columnas_a_tratar:
    df[col] = df[col].str.split()

# %%
df.sample(5)
# Out:
#       customerID  Churn    gender  SeniorCitizen Partner Dependents  tenure  \
# 2323  3237-AJGEH  [yes]  [female]              0   [yes]      [yes]       3
# 3545  4884-TVUQF   [no]  [female]              1    [no]       [no]      57
# 3373  4685-TFLLS   [no]    [male]              0   [yes]      [yes]      18
# 5973  8165-ZJRNM   [no]  [female]              0   [yes]      [yes]      72
# 3131  4365-MSDYN   [no]    [male]              0   [yes]       [no]       8
#
#      PhoneService         MultipleLines InternetService  ...  \
# 2323         [no]  [no, phone, service]           [dsl]  ...
# 3545        [yes]                 [yes]  [fiber, optic]  ...
# 3373        [yes]                  [no]            [no]  ...
# 5973        [yes]                 [yes]            [no]  ...
# 3131        [yes]                  [no]            [no]  ...
#
#                  OnlineBackup         DeviceProtection  \
# 2323                     [no]                     [no]
# ...

# %% [markdown]
# ###Columna de cuentas diarias

# %%
df['Cuentas_Diarias'] = round(df['Charges.Monthly']/30, 2)

# %%
df.sample(5)
# Out:
#       customerID  Churn    gender  SeniorCitizen Partner Dependents  tenure  \
# 5365  7322-OCWHC   [no]    [male]              1   [yes]       [no]      72
# 24    0031-PVLZI  [yes]  [female]              0   [yes]      [yes]       4
# 6187  8480-PPONV   [no]    [male]              0   [yes]      [yes]      62
# 489   0691-IFBQW  [yes]  [female]              1    [no]       [no]      46
# 35    0056-EPFBG   [no]    [male]              0   [yes]      [yes]      20
#
#      PhoneService         MultipleLines InternetService  ...  \
# 5365        [yes]                 [yes]  [fiber, optic]  ...
# 24          [yes]                  [no]            [no]  ...
# 6187        [yes]                 [yes]  [fiber, optic]  ...
# 489         [yes]                 [yes]  [fiber, optic]  ...
# 35           [no]  [no, phone, service]           [dsl]  ...
#
#              DeviceProtection              TechSupport  \
# 5365                    [yes]                    [yes]
# ...

# %%
df.dtypes
# Out:
# customerID           object
# Churn                object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# Charges.Monthly     float64
# Charges.Total       float64
# Cuentas_Diarias     float64
# dtype: object

# %%
df.to_json('/content/drive/MyDrive/Pandas/Churn_de_Clientes.json', index=False)
df = pd.read_json('/content/drive/MyDrive/Pandas/Churn_de_Clientes.json')
df.head()
# Out:
#    customerID  Churn    gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO   [no]  [female]              0   [yes]      [yes]       9
# 1  0003-MKNFE   [no]    [male]              0    [no]       [no]       9
# 2  0004-TLHLJ  [yes]    [male]              0    [no]       [no]       4
# 3  0011-IGKFF  [yes]    [male]              1   [yes]       [no]      13
# 4  0013-EXCHZ  [yes]  [female]              1   [yes]       [no]       3
#
#   PhoneService MultipleLines InternetService  ... DeviceProtection  \
# 0        [yes]          [no]           [dsl]  ...             [no]
# 1        [yes]         [yes]           [dsl]  ...             [no]
# 2        [yes]          [no]  [fiber, optic]  ...            [yes]
# 3        [yes]          [no]  [fiber, optic]  ...            [yes]
# 4        [yes]          [no]  [fiber, optic]  ...             [no]
#
#   TechSupport StreamingTV StreamingMovies            Contract  \
# ...

# %% [markdown]
# #📊 Carga y análisis

# %% [markdown]
# ###Análisis Descriptivo

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  Charges.Monthly  Charges.Total  \
# count    7267.000000  7267.000000      7267.000000    7256.000000
# mean        0.162653    32.346498        64.720098    2280.634213
# std         0.369074    24.571773        30.129572    2268.632997
# min         0.000000     0.000000        18.250000      18.800000
# 25%         0.000000     9.000000        35.425000     400.225000
# 50%         0.000000    29.000000        70.300000    1391.000000
# 75%         0.000000    55.000000        89.875000    3785.300000
# max         1.000000    72.000000       118.750000    8684.800000
#
#        Cuentas_Diarias
# count      7267.000000
# mean          2.157292
# std           1.004407
# min           0.610000
# 25%           1.180000
# 50%           2.340000
# 75%           2.995000
# max           3.960000

# %% [markdown]
# ###Distribución de evasión

# %%
df['Churn'].value_counts()
# Out:
# Churn
# [no]     5174
# [yes]    1869
# []        224
# Name: count, dtype: int64

# %%
#Asistencia de IA
churn_negativo = df['Churn'].apply(lambda x: 'no' in x)

df[churn_negativo]
# Out:
#       customerID Churn    gender  SeniorCitizen Partner Dependents  tenure  \
# 0     0002-ORFBO  [no]  [female]              0   [yes]      [yes]       9
# 1     0003-MKNFE  [no]    [male]              0    [no]       [no]       9
# 5     0013-MHZWF  [no]  [female]              0    [no]      [yes]       9
# 6     0013-SMEOE  [no]  [female]              1   [yes]       [no]      71
# 7     0014-BMAQU  [no]    [male]              0   [yes]       [no]      63
# ...          ...   ...       ...            ...     ...        ...     ...
# 7259  9979-RGMZT  [no]  [female]              0    [no]       [no]       7
# 7262  9987-LUTYD  [no]  [female]              0    [no]       [no]      13
# 7264  9992-UJOEL  [no]    [male]              0    [no]       [no]       2
# 7265  9993-LHIEB  [no]    [male]              0   [yes]      [yes]      67
# 7266  9995-HOTOH  [no]    [male]              0   [yes]      [yes]      63
#
# ...

# %%
churn_positivo = df['Churn'].apply(lambda x: 'yes' in x)

df[churn_positivo]
# Out:
#       customerID  Churn    gender  SeniorCitizen Partner Dependents  tenure  \
# 2     0004-TLHLJ  [yes]    [male]              0    [no]       [no]       4
# 3     0011-IGKFF  [yes]    [male]              1   [yes]       [no]      13
# 4     0013-EXCHZ  [yes]  [female]              1   [yes]       [no]       3
# 18    0022-TCJCI  [yes]    [male]              1    [no]       [no]      45
# 19    0023-HGHWL  [yes]    [male]              1    [no]       [no]       1
# ...          ...    ...       ...            ...     ...        ...     ...
# 7243  9961-JBNMK  [yes]    [male]              1    [no]       [no]      21
# 7246  9965-YOKZB  [yes]    [male]              1    [no]       [no]       9
# 7260  9985-MWVIX  [yes]  [female]              0    [no]       [no]       1
# 7261  9986-BONCE  [yes]  [female]              0    [no]       [no]       4
# 7263  9992-RRAMN  [yes]    [male]              0   [yes]       [no]      22
#
# ...

# %%
churn_nulo = df['Churn'].apply(lambda x: x == [])
df[churn_nulo]
# Out:
#       customerID Churn    gender  SeniorCitizen Partner Dependents  tenure  \
# 30    0047-ZHDTW    []  [female]              0    [no]       [no]      11
# 75    0120-YZLQA    []    [male]              0    [no]       [no]      71
# 96    0154-QYHJU    []    [male]              0    [no]       [no]      29
# 98    0162-RZGMZ    []  [female]              1    [no]       [no]       5
# 175   0274-VVQOQ    []    [male]              1   [yes]       [no]      65
# ...          ...   ...       ...            ...     ...        ...     ...
# 7158  9840-GSRFX    []  [female]              0    [no]       [no]      14
# 7180  9872-RZQQB    []  [female]              0   [yes]       [no]      49
# 7211  9920-GNDMB    []    [male]              0    [no]       [no]       9
# 7239  9955-RVWSC    []  [female]              0   [yes]      [yes]      67
# 7247  9966-VYRTZ    []  [female]              0   [yes]      [yes]      31
#
#      PhoneService         MultipleLines InternetService  ...  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
#Asistencia de IA
churn = [churn_negativo.sum(), churn_positivo.sum(), churn_nulo.sum()]
particiones = ['Datos\n nulos','Clientes\n perdidos','Clientes\n leales']

# %%
colores1 = ['silver','rosybrown','slateblue']

fig, ax = plt.subplots(figsize=(10, 6))

ax.set_frame_on(False)
ax.xaxis.set_visible(False)

churn_sorted = sorted(churn)

ax.barh(particiones, churn_sorted, color=colores1)
ax.set_title('Churn de Clientes')

for i,j in enumerate(churn_sorted):
    ax.text(j+20,i,str(j),color='black',fontsize=8.5,ha='left',va='center')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.pie(churn_sorted, labels=particiones, autopct='%1.1f%%', colors=colores1)
ax.set_title('Churn de Clientes')
plt.show()

# %% [markdown]
# ###Recuento de evasión por variables categóricas

# %%
churn_de_clientes = df[churn_positivo].copy()

# %%
churn_de_clientes.to_json('/content/drive/MyDrive/Pandas/evasion_de_clientes.json')
df = pd.read_json('/content/drive/MyDrive/Pandas/evasion_de_clientes.json')

df.sample(3)
# Out:
#       customerID  Churn    gender  SeniorCitizen Partner Dependents  tenure  \
# 887   1251-KRREG  [yes]    [male]              0    [no]       [no]       2
# 6741  9286-DOJGF  [yes]  [female]              1   [yes]       [no]      38
# 5298  7240-FQLHE  [yes]  [female]              1   [yes]       [no]      18
#
#      PhoneService MultipleLines InternetService  ... DeviceProtection  \
# 887         [yes]         [yes]           [dsl]  ...             [no]
# 6741        [yes]         [yes]  [fiber, optic]  ...             [no]
# 5298        [yes]         [yes]  [fiber, optic]  ...             [no]
#
#      TechSupport StreamingTV StreamingMovies            Contract  \
# 887         [no]        [no]            [no]  [month, to, month]
# 6741        [no]        [no]            [no]  [month, to, month]
# 5298       [yes]       [yes]           [yes]  [month, to, month]
#
#      PaperlessBilling                PaymentMethod Charges.Monthly  \
# ...

# %%
columnas_factor = ['gender','tenure','PhoneService','MultipleLines','InternetService','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies','Contract','PaperlessBilling','PaymentMethod']

# %%
#Asistencia de IA
for col in columnas_factor:
    print(f"Value counts for column: {col}")
    print(df[col].value_counts())
    print("\n" + "="*30 + "\n")
# Out:
# Value counts for column: gender
# gender
# [female]    939
# [male]      930
# Name: count, dtype: int64
#
# ...
#
# Value counts for column: tenure
# tenure
# 1     380
# 2     123
# 3      94
# 4      83
# 5      64
#      ...
# 72      6
# 44      6
# 62      5
# 64      4
# 63      4
# Name: count, Length: 72, dtype: int64
#
# ...
#
# Value counts for column: PhoneService
# PhoneService
# [yes]    1699
# [no]      170
# Name: count, dtype: int64
#
# ...
#
# Value counts for column: MultipleLines
# MultipleLines
# [yes]                   850
# [no]                    849
# [no, phone, service]    170
# Name: count, dtype: int64
#
# ...
#
# Value counts for column: InternetService
# InternetService
# [fiber, optic]    1297
# [dsl]              459
# [no]               113
# Name: count, dtype: int64
#
# ...
#
# Value counts for column: OnlineSecurity
# OnlineSecurity
# [no]                       1461
# [yes]                       295
# [no, internet, service]     113
# Name: count, dtype: int64
#
# ...
#
# ...

# %%
import seaborn as sns

paleta = sns.color_palette('viridis')

# %%
def filtro_por_palabra(columna, palabra):
    return df[columna].apply(lambda x: palabra in x)

# %%
def graficar_filtros(filtro, etiquetas, titulo):
    fig, ax = plt.subplots(figsize=(10, 6))
    ax.pie(filtro, labels=etiquetas, autopct='%1.1f%%', colors=paleta)
    ax.set_title(titulo)
    plt.show()

# %%
femenino = filtro_por_palabra('gender','female')
masculino = filtro_por_palabra('gender','male')
genero = [femenino.sum(), masculino.sum()]
labels_genero = ['Mujeres','Hombres']

graficar_filtros(genero, labels_genero,'Género de Clientes\n perdidos')

# %%
#Asistencia de IA
a_dos_anios = df[df['Contract'].apply(lambda x:'two' in x)]['tenure'].value_counts().sort_index()
a_un_anio = df[df['Contract'].apply(lambda x:'one' in x)]['tenure'].value_counts().sort_index()
mes_a_mes = df[df['Contract'].apply(lambda x:'month' in x)]['tenure'].value_counts().sort_index()
contrato = [a_dos_anios.sum(), a_un_anio.sum(), mes_a_mes.sum()]
labels_contrato = ['A dos años','A un año','Mes a mes']

fig, ax = plt.subplots(2, 2, figsize=(12, 8))

ax[0,0].pie(contrato, labels=labels_contrato, autopct='%1.1f%%', colors=paleta)
ax[0,0].set_title('Tipos de contrato')

ax[0,1].bar(a_dos_anios.index, a_dos_anios.values, color=paleta)
ax[0,1].set_title('Antigüedad en Contratos "Dos años"')
ax[0,1].set_xlabel('Meses')
ax[0,1].set_ylabel('Número de clientes')

ax[1,0].bar(a_un_anio.index, a_un_anio.values, color=paleta)
ax[1,0].set_title('Antigüedad en Contratos Anuales')
ax[1,0].set_xlabel('Meses')
ax[1,0].set_ylabel('Número de clientes')

ax[1,1].bar(mes_a_mes.index, mes_a_mes.values, color=paleta)
ax[1,1].set_title('Antigüedad en Contratos "Mes a Mes"')
ax[1,1].set_xlabel('Meses')
ax[1,1].set_ylabel('Número de clientes')

plt.tight_layout()
plt.show()

# %%
fibra_optica = filtro_por_palabra('InternetService', 'fiber')
DSL = filtro_por_palabra('InternetService', 'dsl')
Internet_denegado = filtro_por_palabra('InternetService', 'no')
Internet = [fibra_optica.sum(),DSL.sum(),Internet_denegado.sum()]
labels_internet = ['Fibra óptica','DSL','Nulo consumo\n de Internet']

graficar_filtros(Internet, labels_internet, 'Servicio de Internet')

# %%
asistido = filtro_por_palabra('TechSupport', 'yes')
no_asistido = filtro_por_palabra('TechSupport', 'no')
asistencia = [asistido.sum(),no_asistido.sum()]
labels_asistencia = ['Clientes\n atendidos','Clientes no\n atendidos']

graficar_filtros(asistencia, labels_asistencia, 'Asistencia en Clientes')

# %%
#Asistencia de IA
telefonía_consumida = df[df['PhoneService'].apply(lambda x: 'yes' in x if isinstance(x, list) else False)]['MultipleLines']
telefonía_no_consumida = df[df['PhoneService'].apply(lambda x: 'no' in x if isinstance(x, list) else False)]['MultipleLines']

serTelefonia = pd.concat([telefonía_consumida, telefonía_no_consumida]).value_counts()

serTelefonia_counts = serTelefonia.values
serTelefonia_labels = serTelefonia.index

traducciones = {
    ('yes',): 'Servicios de\n telefonía y \n multi-líneas',
    ('no',): 'Servicio de\n telefonía sin\n servicio de\n multi-líneas',
    ('no', 'phone', 'service'): 'Sin servicio\n de telefonía',
}

labels_traducidos = [traducciones.get(tuple(label), label) if isinstance(label, list) else traducciones.get(label, label) for label in serTelefonia_labels]

graficar_filtros(serTelefonia_counts, labels_traducidos, 'Servicio de telefonía\n y multi líneas')

# %%
#Asistencia de IA
df_fiber = df[df['InternetService'].apply(lambda x: 'fiber' in x if isinstance(x, list) else False)]

fiber_security_yes = df_fiber['OnlineSecurity'].apply(lambda x: 'yes' in x if isinstance(x, list) else False).sum()
fiber_backup_yes = df_fiber['OnlineBackup'].apply(lambda x: 'yes' in x if isinstance(x, list) else False).sum()
fiber_protection_yes = df_fiber['DeviceProtection'].apply(lambda x: 'yes' in x if isinstance(x, list) else False).sum()

df_dsl = df[df['InternetService'].apply(lambda x: 'dsl' in x if isinstance(x, list) else False)]

dsl_security_yes = df_dsl['OnlineSecurity'].apply(lambda x: 'yes' in x if isinstance(x, list) else False).sum()
dsl_backup_yes = df_dsl['OnlineBackup'].apply(lambda x: 'yes' in x if isinstance(x, list) else False).sum()
dsl_protection_yes = df_dsl['DeviceProtection'].apply(lambda x: 'yes' in x if isinstance(x, list) else False).sum()

serInternet = [fiber_security_yes + dsl_security_yes,
               fiber_backup_yes + dsl_backup_yes,
               fiber_protection_yes + dsl_protection_yes]

serInternet_labels = ['Seguridad\n en línea', 'Backup', 'Protection\n para\n dispositivos']

fig, ax = plt.subplots(figsize=(10, 6))

ax.set_frame_on(False)
ax.xaxis.set_visible(False)



ax.barh(serInternet_labels, serInternet, color=paleta)
ax.set_title('Servicios adicionales')

for i,j in enumerate(serInternet):
    ax.text(j+20,i,str(j),color='black',fontsize=8.5,ha='left',va='center')

plt.show()

# %%
serTV = filtro_por_palabra('StreamingTV', 'yes')
serMovies = filtro_por_palabra('StreamingMovies','yes')
streaming = [serTV.sum(),serMovies.sum()]
labels_streaming = ['Streaming TV','Streaming\n Películas']

graficar_filtros(streaming, labels_streaming, 'Streaming TV\n vs\n Streaming Películas')

# %%
#Asistencia de IA
pago_online_values = filtro_por_palabra('PaperlessBilling','yes')
pago_offline_values = filtro_por_palabra('PaperlessBilling','no')

pago_online = [pago_online_values.sum(), pago_offline_values.sum()]
pago_online_labels = ['Factura\n en línea', 'Factura\n tradicional']

metodosDePago_values = df['PaymentMethod']

traducciones1 = {
    'yes': 'Factura\n en línea',
    'no': 'Factura\n tradicional',
}

labels_traducidos1 = [traducciones1.get(label[0], label[0]) if isinstance(label, list) else traducciones1.get(label, label) for label in pago_online_labels]

metodosDePago = metodosDePago_values.value_counts().values
metodosDePago_labels = metodosDePago_values.value_counts().index

traducciones2 = {
    'electronic': 'Cheques\n electrónicos',
    'mailed': 'Cheques por \n correo',
    'credit': 'Cargos a\n Tarjeta de\n Crédito\n automáticos',
    'bank': 'Transferencias\n de banco\n automáticos',
}

labels_traducidos2 = [traducciones2.get(label[0], label[0]) if isinstance(label, list) else traducciones2.get(label, label) for label in metodosDePago_labels]

fig, ax = plt.subplots(1, 2, figsize=(12, 6))

ax[0].pie(pago_online, labels=labels_traducidos1, autopct='%1.1f%%', startangle=90, colors=paleta)
ax[0].set_title('Método de Facturación', pad=20)

ax[1].pie(metodosDePago, labels=labels_traducidos2, autopct='%1.1f%%', startangle=90,colors=paleta)
ax[1].set_title('Métodos de Pago', pad=20)

plt.tight_layout()
plt.show()

# %% [markdown]
# ###Conteo de evasión por variables numéricas

# %%
df = pd.read_json('/content/drive/MyDrive/Pandas/Churn_de_Clientes.json')
df.head()
# Out:
#    customerID  Churn    gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO   [no]  [female]              0   [yes]      [yes]       9
# 1  0003-MKNFE   [no]    [male]              0    [no]       [no]       9
# 2  0004-TLHLJ  [yes]    [male]              0    [no]       [no]       4
# 3  0011-IGKFF  [yes]    [male]              1   [yes]       [no]      13
# 4  0013-EXCHZ  [yes]  [female]              1   [yes]       [no]       3
#
#   PhoneService MultipleLines InternetService  ... DeviceProtection  \
# 0        [yes]          [no]           [dsl]  ...             [no]
# 1        [yes]         [yes]           [dsl]  ...             [no]
# 2        [yes]          [no]  [fiber, optic]  ...            [yes]
# 3        [yes]          [no]  [fiber, optic]  ...            [yes]
# 4        [yes]          [no]  [fiber, optic]  ...             [no]
#
#   TechSupport StreamingTV StreamingMovies            Contract  \
# ...

# %%
churn_negativo = filtro_por_palabra('Churn','no')
df[churn_negativo]
# Out:
#       customerID Churn    gender  SeniorCitizen Partner Dependents  tenure  \
# 0     0002-ORFBO  [no]  [female]              0   [yes]      [yes]       9
# 1     0003-MKNFE  [no]    [male]              0    [no]       [no]       9
# 5     0013-MHZWF  [no]  [female]              0    [no]      [yes]       9
# 6     0013-SMEOE  [no]  [female]              1   [yes]       [no]      71
# 7     0014-BMAQU  [no]    [male]              0   [yes]       [no]      63
# ...          ...   ...       ...            ...     ...        ...     ...
# 7259  9979-RGMZT  [no]  [female]              0    [no]       [no]       7
# 7262  9987-LUTYD  [no]  [female]              0    [no]       [no]      13
# 7264  9992-UJOEL  [no]    [male]              0    [no]       [no]       2
# 7265  9993-LHIEB  [no]    [male]              0   [yes]      [yes]      67
# 7266  9995-HOTOH  [no]    [male]              0   [yes]      [yes]      63
#
# ...

# %%
churn_positivo = filtro_por_palabra('Churn','yes')
df[churn_positivo]
# Out:
#       customerID  Churn    gender  SeniorCitizen Partner Dependents  tenure  \
# 2     0004-TLHLJ  [yes]    [male]              0    [no]       [no]       4
# 3     0011-IGKFF  [yes]    [male]              1   [yes]       [no]      13
# 4     0013-EXCHZ  [yes]  [female]              1   [yes]       [no]       3
# 18    0022-TCJCI  [yes]    [male]              1    [no]       [no]      45
# 19    0023-HGHWL  [yes]    [male]              1    [no]       [no]       1
# ...          ...    ...       ...            ...     ...        ...     ...
# 7243  9961-JBNMK  [yes]    [male]              1    [no]       [no]      21
# 7246  9965-YOKZB  [yes]    [male]              1    [no]       [no]       9
# 7260  9985-MWVIX  [yes]  [female]              0    [no]       [no]       1
# 7261  9986-BONCE  [yes]  [female]              0    [no]       [no]       4
# 7263  9992-RRAMN  [yes]    [male]              0   [yes]       [no]      22
#
# ...

# %%
df_cuentas = pd.DataFrame({
    'customerID':df['customerID'],
    'Churn':df['Churn'],
    'Charges.Monthly':df['Charges.Monthly'],
    'Charges.Total':df['Charges.Total'],
    'Cuentas_Diarias':df['Cuentas_Diarias']
})

# %%
df_cuentas.to_json('/content/drive/MyDrive/Pandas/Cuentas_clientes.json')
df = pd.read_json('/content/drive/MyDrive/Pandas/Cuentas_clientes.json')
df.sample(3)
# Out:
#       customerID  Churn  Charges.Monthly  Charges.Total  Cuentas_Diarias
# 6038  8242-JSVBO   [no]            44.65          322.5             1.49
# 2247  3137-NYQQI   [no]            64.80         1175.6             2.16
# 843   1196-AMORA  [yes]            73.60          520.0             2.45

# %%
df[churn_negativo][['Charges.Monthly','Charges.Total','Cuentas_Diarias']].describe()
# Out:
#        Charges.Monthly  Charges.Total  Cuentas_Diarias
# count      5174.000000    5163.000000      5174.000000
# mean         61.265124    2555.344141         2.042080
# std          31.092648    2329.456984         1.036492
# min          18.250000      18.800000         0.610000
# 25%          25.100000     577.825000         0.840000
# 50%          64.425000    1683.600000         2.150000
# 75%          88.400000    4264.125000         2.950000
# max         118.750000    8672.450000         3.960000

# %%
df[churn_positivo][['Charges.Monthly','Charges.Total','Cuentas_Diarias']].describe()
# Out:
#        Charges.Monthly  Charges.Total  Cuentas_Diarias
# count      1869.000000    1869.000000      1869.000000
# mean         74.441332    1531.796094         2.481450
# std          24.666053    1890.822994         0.822287
# min          18.850000      18.850000         0.630000
# 25%          56.150000     134.500000         1.870000
# 50%          79.650000     703.550000         2.660000
# 75%          94.200000    2331.300000         3.140000
# max         118.350000    8684.800000         3.940000

# %%
df[churn_negativo][['Charges.Monthly','Charges.Total','Cuentas_Diarias']].corr()
# Out:
#                  Charges.Monthly  Charges.Total  Cuentas_Diarias
# Charges.Monthly         1.000000       0.757110         0.999996
# Charges.Total           0.757110       1.000000         0.757131
# Cuentas_Diarias         0.999996       0.757131         1.000000

# %%
df[churn_positivo][['Charges.Monthly','Charges.Total','Cuentas_Diarias']].corr()
# Out:
#                  Charges.Monthly  Charges.Total  Cuentas_Diarias
# Charges.Monthly         1.000000       0.545772         0.999993
# Charges.Total           0.545772       1.000000         0.545875
# Cuentas_Diarias         0.999993       0.545875         1.000000

# %%
#Asistencia de IA
df['segmento_total'] = pd.qcut(df['Charges.Total'], q=3, labels=['bajo', 'medio', 'alto'])

# %%
df[churn_negativo]['segmento_total']
# Out:
# 0        bajo
# 1        bajo
# 5        bajo
# 6        alto
# 7        alto
#         ...
# 7259     bajo
# 7262    medio
# 7264     bajo
# 7265     alto
# 7266     alto
# Name: segmento_total, Length: 5174, dtype: category
# Categories (3, object): ['bajo' < 'medio' < 'alto']

# %%
comportamiento1_counts = df[churn_negativo]['segmento_total'].value_counts()
comportamiento1_values = comportamiento1_counts.values
labels_comportamiento1 = comportamiento1_counts.index

graficar_filtros(comportamiento1_values, labels_comportamiento1, 'Comportamiento\n de clientes\n leales por\n monto')

# %%
df[churn_positivo]['segmento_total']
# Out:
# 2        bajo
# 3       medio
# 4        bajo
# 18       alto
# 19       bajo
#         ...
# 7243    medio
# 7246    medio
# 7260     bajo
# 7261     bajo
# 7263    medio
# Name: segmento_total, Length: 1869, dtype: category
# Categories (3, object): ['bajo' < 'medio' < 'alto']

# %%
comportamiento2_counts = df[churn_positivo]['segmento_total'].value_counts()
comportamiento2_values = comportamiento2_counts.values
labels_comportamiento2 = comportamiento2_counts.index

graficar_filtros(comportamiento2_values, labels_comportamiento2, 'Comportamiento\n de clientes\n perdidos por\n monto')

# %%
import plotly.express as px

# %%
#Asistencia de IA
df['frecuencia'] = df['Charges.Total'] / df['Charges.Monthly']

# %%
frecuenciaCN = df[churn_negativo]['frecuencia']

# %%
#Asistencia de IA
frecuenciaCN_df = frecuenciaCN.reset_index()
frecuenciaCN_df = frecuenciaCN_df.rename(columns={'index': 'Customer Index'})

fig = px.line(frecuenciaCN_df, x='Customer Index', y='frecuencia')
fig.update_layout(
    xaxis_title='Monto total\n por cliente',
    yaxis_title='Monto mensual\n por cliente'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
frecuenciaCP = df[churn_positivo]['frecuencia']

# %%
frecuenciaCP_df = frecuenciaCP.reset_index()
frecuenciaCP_df = frecuenciaCP_df.rename(columns={'index': 'Customer Index'})

fig = px.line(frecuenciaCN_df, x='Customer Index', y='frecuencia')
fig.update_layout(
    xaxis_title='Monto total\n por cliente',
    yaxis_title='Monto mensual\n por cliente'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.head()
# Out:
#    customerID  Churn  Charges.Monthly  Charges.Total  Cuentas_Diarias  \
# 0  0002-ORFBO   [no]             65.6         593.30             2.19
# 1  0003-MKNFE   [no]             59.9         542.40             2.00
# 2  0004-TLHLJ  [yes]             73.9         280.85             2.46
# 3  0011-IGKFF  [yes]             98.0        1237.85             3.27
# 4  0013-EXCHZ  [yes]             83.9         267.40             2.80
#
#   segmento_total  frecuencia
# 0           bajo    9.044207
# 1           bajo    9.055092
# 2           bajo    3.800406
# 3          medio   12.631122
# 4           bajo    3.187128

# %%
monto_mensualCN = df[churn_negativo]['Charges.Monthly']
monto_mensualCP = df[churn_positivo]['Charges.Monthly']

# %%
monto_totalCN = df[churn_negativo]['Charges.Total']
monto_totalCP = df[churn_positivo]['Charges.Total']

# %%
#Asistencia de IA
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x=monto_totalCN, y=monto_mensualCN, alpha=0.6, color='green')
plt.axhline(y=monto_mensualCN.median(), color='r', linestyle='--', label='Mediana mensual')
plt.axvline(x=monto_totalCN.quantile(0.9), color='g', linestyle='--', label='Percentil 90 total')
plt.title('Clientes leales: Monto Total vs. Monto Mensual')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x=monto_totalCP, y=monto_mensualCP, alpha=0.6, color='crimson')
plt.axhline(y=monto_mensualCP.median(), color='r', linestyle='--', label='Mediana mensual')
plt.axvline(x=monto_totalCP.quantile(0.9), color='g', linestyle='--', label='Percentil 90 total')
plt.title('Clientes perdidos: Monto Total vs. Monto Mensual')
plt.legend()
plt.show()

# %%
df.head()
# Out:
#    customerID  Churn  Charges.Monthly  Charges.Total  Cuentas_Diarias  \
# 0  0002-ORFBO   [no]             65.6         593.30             2.19
# 1  0003-MKNFE   [no]             59.9         542.40             2.00
# 2  0004-TLHLJ  [yes]             73.9         280.85             2.46
# 3  0011-IGKFF  [yes]             98.0        1237.85             3.27
# 4  0013-EXCHZ  [yes]             83.9         267.40             2.80
#
#   segmento_total  frecuencia
# 0           bajo    9.044207
# 1           bajo    9.055092
# 2           bajo    3.800406
# 3          medio   12.631122
# 4           bajo    3.187128

# %%
#Alta asistencia de IA

# Filtrar clientes leales y ausentes
df_negativo = df[churn_negativo].copy()
df_positivo = df[churn_positivo].copy()

# Calcular la columna 'alto_total' para clientes leales
df_negativo['alto_total'] = df_negativo['Charges.Total'] > df_negativo['Charges.Total'].quantile(0.9)  # Top 10% en monto total

# Graficar boxplot para clientes leales
plt.figure(figsize=(8, 5))
sns.boxplot(data=df_negativo, x='alto_total', y='Charges.Monthly')
plt.title('Distribución de Monto Mensual en Clientes leales con Alto vs. Bajo Monto Total')
plt.xticks([False, True], ['Bajo Total', 'Alto Total'])
plt.show()

# Calcular la columna 'alto_total' para clientes ausentes
df_positivo['alto_total'] = df_positivo['Charges.Total'] > df_positivo['Charges.Total'].quantile(0.9)

# Graficar boxplot para clientes ausentes
plt.figure(figsize=(8, 5))
sns.boxplot(data=df_positivo, x='alto_total', y='Charges.Monthly')
plt.title('Distribución de Monto Mensual en Clientes perdidos con Alto vs. Bajo Monto Total')
plt.xticks([False, True], ['Bajo Total', 'Alto Total'])
plt.show()

# Para las siguientes visualizaciones, volvemos a cargar el DataFrame original
# o aseguramos que contiene las columnas necesarias si no queremos recargarlo.
# Asumiendo que df ya contiene todas las columnas necesarias después de la normalización.

# Filtrar clientes con alto total y bajo mensual para clientes leales
# Asegurarse de que 'customerID' es la columna correcta para el ID del cliente
# y que las columnas 'Charges.Total' y 'Charges.Monthly' existen y son numéricas
clientes_interesantes_negativo = df_negativo[(df_negativo['Charges.Total'] > df_negativo['Charges.Total'].quantile(0.9)) &
                                           (df_negativo['Charges.Monthly'] < df_negativo['Charges.Monthly'].median())].copy()

# Tomar los top 10 para visualización
top_clientes_negativo = clientes_interesantes_negativo.sort_values('Charges.Total', ascending=False).head(10)

# Verificar si 'customerID' es la columna correcta. Si no, reemplazar con la columna de ID correcta.
if 'customerID' in top_clientes_negativo.columns:
    # Add check for empty DataFrame before plotting
    if not top_clientes_negativo.empty:
        top_clientes_negativo.set_index('customerID')[['Charges.Total', 'Charges.Monthly']].plot(kind='bar', stacked=True)
        plt.title('Top 10 Clientes Leales: Alto Total vs. Bajo Mensual')
        plt.ylabel('Monto')
        plt.show()
    else:
        print("No se encontraron clientes leales que cumplan con los criterios de alto Total y bajo Mensual para graficar.")

else:
    print("Error: La columna 'customerID' no se encuentra en el DataFrame. Por favor, verifique el nombre de la columna del ID del cliente.")


# Crear una columna adicional: ratio total/mensual para clientes leales
df_negativo['ratio_total_mensual'] = df_negativo['Charges.Total'] / df_negativo['Charges.Monthly']

# Filtrar solo clientes relevantes (alto ratio)
clientes_filtrados_negativo = df_negativo[df_negativo['ratio_total_mensual'] > df_negativo['ratio_total_mensual'].quantile(0.9)]

# Heatmap para clientes leales
# Asegurarse de que 'Cuentas_Diarias' existe
if 'Cuentas_Diarias' in clientes_filtrados_negativo.columns:
    # Add check for empty DataFrame before plotting heatmap
    if not clientes_filtrados_negativo.empty:
        sns.heatmap(clientes_filtrados_negativo[['Charges.Total', 'Charges.Monthly', 'ratio_total_mensual', 'Cuentas_Diarias']].corr(), annot=True)
        plt.title('Correlaciones en Clientes Leales con Alto Ratio Total/Mensual')
        plt.show()
    else:
        print("No se encontraron clientes leales con alto ratio Total/Mensual para el heatmap.")
else:
    print("Error: La columna 'Cuentas_Diarias' no se encuentra en el DataFrame filtrado para heatmap. Por favor, verifique el nombre de la columna.")

# Repetir análisis similar para clientes ausentes si es necesario
# Filtrar clientes con alto total y bajo mensual para clientes ausentes
clientes_interesantes_positivo = df_positivo[(df_positivo['Charges.Total'] > df_positivo['Charges.Total'].quantile(0.9)) &
                                           (df_positivo['Charges.Monthly'] < df_positivo['Charges.Monthly'].median())].copy()

# Tomar los top 10 para visualización
top_clientes_positivo = clientes_interesantes_positivo.sort_values('Charges.Total', ascending=False).head(10)

# Verificar si 'customerID' es la columna correcta. Si no, reemplazar con la columna de ID correcta.
if 'customerID' in top_clientes_positivo.columns:
    # Add check for empty DataFrame before plotting
    if not top_clientes_positivo.empty:
        top_clientes_positivo.set_index('customerID')[['Charges.Total', 'Charges.Monthly']].plot(kind='bar', stacked=True)
        plt.title('Top 10 Clientes Perdidos: Alto Total vs. Bajo Mensual')
        plt.ylabel('Monto')
        plt.show()
    else:
        print("No se encontraron clientes ausentes que cumplan con los criterios de alto Total y bajo Mensual para graficar.")
else:
    print("Error: La columna 'customerID' no se encuentra en el DataFrame. Por favor, verifique el nombre de la columna del ID del cliente.")


# Crear una columna adicional: ratio total/mensual para clientes ausentes
df_positivo['ratio_total_mensual'] = df_positivo['Charges.Total'] / df_positivo['Charges.Monthly']

# Filtrar solo clientes relevantes (alto ratio)
clientes_filtrados_positivo = df_positivo[df_positivo['ratio_total_mensual'] > df_positivo['ratio_total_mensual'].quantile(0.9)]

# Heatmap para clientes ausentes
# Asegurarse de que 'Cuentas_Diarias' existe
if 'Cuentas_Diarias' in clientes_filtrados_positivo.columns:
    # Add check for empty DataFrame before plotting heatmap
    if not clientes_filtrados_positivo.empty:
        sns.heatmap(clientes_filtrados_positivo[['Charges.Total', 'Charges.Monthly', 'ratio_total_mensual', 'Cuentas_Diarias']].corr(), annot=True)
        plt.title('Correlaciones en Clientes Perdidos con Alto Ratio Total/Mensual')
        plt.show()
    else:
        print("No se encontraron clientes ausentes con alto ratio Total/Mensual para el heatmap.")
else:
    print("Error: La columna 'Cuentas_Diarias' no se encuentra en el DataFrame filtrado para heatmap. Por favor, verifique el nombre de la columna.")
# Out:
# No se encontraron clientes leales que cumplan con los criterios de alto Total y bajo Mensual para graficar.

# %% [markdown]
# #📄Informe final

# %% [markdown]
# 🔹 Introducción:
#
# El ETL(Extracción, Transformación y Carga) aplicado al conjunto de datos del archivo 'TelecomX_Data.json' tiene el objetivo de analizar y encontrar patrones de información que nos ayuden a identificar las causas de la evasión('churn') de clientes, posible aspecto
# generador de problemas de impacto, cómo perdida de ingresos, perjuicio de reputación a la marca, entre otros.

# %% [markdown]
# 🔹 Limpieza y Tratamiento de Datos:
#
#    • Extracción
# Primero se importó la biblioteca Pandas con el alías de pd.
# Se extrajo el archivo 'TelecomX_Data.json' de una dirección URL, luego se le almacenó en una variable llamada url y posteriormente, en otra variable (df), se almacenó el método pd.read_json(), con la variable url como argumento, para convertirlo en un Dataframe.
#
#    • Transformación
#
# Se aplicó el .shape las dimensiones del Dataframe, .columns para conocer las columnas que lo conforman, se exploraron cada una de las columnas que contenían diccionarios, y con .dtypes y .info() accedimos a los tipos de datos de todas las columnas, dando este paso exploración de datos.
#
# El siguiente paso es la normalización de las columnas exploradas, con el método pd.json_normalize(), luego con el método pd.DataFrame() se crea un nuevo archivo con un Dataframe ya normalizado, volviendo a explorar sus datos.
#
# Para excluir clientes duplicados, se aplicó .unique(), a la columna que contiene el ID de los mismo, .value_counts() a la columna 'Churn' para conocer la
#  cantidad de clientes que prescindieron del negocio , los que y los que no se tienen ese dato. También se aplicó el método df.isnull().sum(), que devuelve la cantidad de datos nulos de cada columna.
#
# Se agruparon tres subconjuntos de datos en tres variables: [churn_negativo] para los clientes leales, [churn_positivo] para los clientes perdidos y [churn_nulo] para esos clientes del que no tiene ese dato. Dando como paso a la comprobación de inconsistencias.
#
# Lo siguiente es el manejo de las inconsistencias encontradas.Se importó la biblioteca Numpy como np. Hubo una columna a la que se le tuvo el tipo de datos de objet a float64, para que la serie sea de números flotantes, con el método .astype(np.float64).
#
# A las columnas que sus datos son texto, se tuvieron que agruparlas en una lista, y con un for convertirlas en minúsculas con .lower(), a una columna se le tuvo que reemplazar los -(guiones) por espacios, y con otro for y .split() se convirtieron también en listas.
#
# Para terminar se creó una columna 'Cuentas_Diarias', que contiene la serie 'Charges.Monthly' dividido entre 30, que es el promedio de los día del mes.
#
# Por último, con el método .to_json(), el Dataframe resultante se guardó en un nuevo archivo 'Churn_de_Clientes.json'.

# %% [markdown]
# 🔹 Análisis Exploratorio de Datos:
#
#    • Análisis Descriptivo
#
# El método .describe() nos información de la media, la moda, los cuarteles y el valor maximo y el mínimo de las columnas del Dataframe.
#
#    • Distribución de evasión
#
# Con funciones lambda se definieron mejor las variables churn_negativo, churn_positivo y churn_nulo y se importó la biblioteca Matplotlib como plt.
#
# Se trazaron un gráfico de barras con las cantidades de los segmentos de los clientes y un gráfico pastel con los porcentajes que representan a éstos, arrojando lo siguiente:
#
# ~ La cantidad de clientes leales son: 5174, (71.2%);
# ~ La cantidad de clientes perdidos son: 1869, (25.7%);
# ~ La cantidad de clientes en nulo: 224, (3.1%).
#
#    • Recuento de evasión por variables categóricas
#
# En esta sección se generó el archivo 'evasion_de_clientes.json' para poder analizar solo a aquellos clientes que  'abandonaron' el consumo del servicio (churn_positivo) y también se agruparon en una lista aquellas columnas que aportan información relevante del Dataframe, para luego con un for y el método.value_counts() obtener valores.
#
# Además se importó la biblioteca Seaborn dándole como alías sns, para aplicar una paleta de colores más llamativa a los gráficos.
#
# Se agregaron dos funciones definitas para poderlas reutilizar tanto en la obtención de datos a representar como para trazar la mayoría de los gráficos.
#
# Los gráficos correspondientes arrojando lo siguiente de los clientes perdidos:
#    Género
# ~ 50.2% son mujeres;
# ~ 49.8% son hombres;
#    Contratación
# ~ 88.6% preferían que fuera mensual y más de 350 duraron un mes de consumo;
# ~ 8.9% preferían que fuera anual y solo 14 duraron más de 4 años de consumo;
# ~ preferían que fuera a dos años y solo 10 duraron más de 5 años de consumo;
#    Tipo de conexión
# ~ 59.4% consumía por Fibra óptica;
# ~ 24.6% consumía por tecnología DSL;
# ~ 6% no consumía el servicio de internet;
#    Soporte técnico
# ~ 83.4% no fueron atendidos;
# ~ 16.6% fueron atendidos;
#    Telefonía
# ~ 45.5% consumía el servicio y también el servicio de multi-líneas;
# ~ 45.4% consumía el servicio pero no el servicio de multi-líneas;
# ~ 9.1% no consumía el servicio y tampoco el servicio de multi-líneas;
#    Servicios adicionales
# ~ 545 clientes requerían que sus dispositivos estuvieran protegidos;
# ~ 523 clientes requerían de copias de seguridad (backup);
# ~ 295 clientes requerían de seguridad en linea (Security online);
#    Entretenimiento Streaming
# ~ TV: 49.9%;
# ~ Movies: 50.1%;
#    Facturación
# ~ Facturaban Online: 74.9%;
# ~ Facturaban tradicionalmente: 25.1%;
#    Métodos de pago
# ~ Cheques electrónicos: 57.3%;
# ~ Cheques por correo: 16.5%;
# ~ Transferencias de banco automáticas: 13.8%;
# ~ Cargos a tarjeta de crédito automáticos; 12.4%.
#
#   • Conteo de evasión por variables numéricas
#
# En ésta última sección, se creó el archivo 'Cuentas_clientes.json' a partir de archivo 'Churn_de_Clientes.json' para analizar la capacidad de pago
#  de los clientes leales frente a los
# perdidos.Y se importó la biblioteca plotly.express cómo px, para trazar dos gráficos dinámicos que representan la frecuencia de montos.Además se dividieron en dos segmentos de los clientes en variables, los leales [churn_negativo] y los perdidos [churn_positivo].
#
# Por último, los pertinentes gráficos lanzaron los posteriores resultados:
#
# ~ Los clientes leales pagan al mes menos al largo plazo;
# ~ dando lugar a que sus cargos mensuales sean altamente consistentes, y por ende, sus montos totales;
# ~ Por otra parte, los clientes perdidos pagaban mucho al principio, conforme al tiempo, sus cargos mensuales iban decayendo y siendo bajos antes de irse, resultando ser clientes de corto plazo;
# ~ También el 'Ratio Total/Mensual' es un punto más relevante para los clientes perdidos que para los leales, sobre todo la relación con sus montos totales.

# %% [markdown]
# 🔹 Conclusiones e Insights:
#
# La evasión o 'churn' de clientes es uno de los aspectos importantes a nivel empresarial debido a que ocasiona pérdidas de ingresos y de rentabilidad, también la reputación de la marca, además genera costos tanto operativos como de marketing. Agregando demás que con este hecho, le damos ventaja a nuestra competencia.
#
# Lo cual nos lleva a lo siguiente:
# ~ de los clientes perdidos eran más los que consumían por Fibra óptica que por tecnología DSL;
# ~ más de 80% no recibieron soporte técnico;
# ~ más de 90% consumían el servicio de telefonía;
# ~ alrededor de 3/4 facturaban online;
# ~ más de la mitad pagaban por medio de cheques electrónicos;
# ~ y agregando que son de corto plazo, debido al decremento de sus pagos mensuales;
# ~ en cambio, los clientes leales perduran a causa de la consistencia de sus cargos de mes a mes.

# %% [markdown]
# 🔹 Recomendaciones:
#
# Las sugerencias aquí propuestas se basan en los hallazgos encontrados en el análisis realizado.
#
# Altamente recomiendo:
# ~ prestar mayor atención al área de soporte técnico, formular e implementar acciones de accesibilidad;
# ~ así como a los servicios de telefonía y multi-líneas, acciones de inspección de funcionamiento y de satisfacción;
# ~ evaluar, mejorar y ofrecer métodos de facturación online con el enfoque y objetivo de comodidad del cliente;
# ~ definir mejor los métodos de pago, mientras sean pocos, mejor, que sean prácticos y enfocados a mejorar la experiencia del cliente como usuario;
# ~ evaluar los costos y precios de los servicios por separado;
# ~ y talvez también, empezar la oferta de paquetes de servicios en conjunto con mensualidades fijas y accesibles que se acerquen al promedio de los cargos mensuales de los clientes leales.

# %% [markdown]
# Nota:
#  #Asistencia de IA significa que se ocupó
# Inteligencia artificial como herramienta
# en bloques de código, consulta de
# información y lectura de gráficos.
